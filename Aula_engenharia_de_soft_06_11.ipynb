# %% [markdown]
# <a href="https://colab.research.google.com/github/carolina157244/tecnico-de-programa-o/blob/main/Aula_engenharia_de_soft_06_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores

# %%
2**3
# Out:
# 8

# %%
23//7
# Out:
# 3

# %%
23%3
# Out:
# 2

# %%
5+5*5/5
# Out:
# 10.0

# %%
4 ** (4//2) + 7
# Out:
# 23

# %%
# Tarefa 1
"""
Faça um programa que leia dois números
inteiros e mostre o somatório entre eles.
"""
a=int(input("informe o número:"))
b=int(input("informe o número:"))
print("o resultado é ",a+b)
# Out:
# informe o número:25
# informe o número:5
# o resultado é  30

# %%
# Tarefa 2
##Faça um programa que calcule a nota final do aluno
nota1=float(input("informe a nota da P1:"));
nota2=float(input("informe a nota da P2:"));
print("Sua nota é",(nota1+nota2) / 2)
# Out:
# informe a nota da P1:6
# informe a nota da P2:5
# Sua nota é 5.5

# %%
# Tarefa 3
nome = 'Carolina'
print('Olá, ' + nome + '!')
print('Olá, ' ,nome +'!')
print('Olá', nome + '!', sep=', ')
print(f' Olá, {nome}!')
# Out:
# Olá, Carolina!
# Olá,  Carolina!
# Olá, Carolina!
#  Olá, Carolina!

# %%
# Tarefa 4
print (f'Digite seu nome')
nome_usuario = input()
print (f'Digite seu ano de nascimento (formato AAAA)')
ano_nascimento = input()
print (f'Olá{nome_usuario}, você nasceu em{ano_nascimento}')
# Out:
# Digite seu nome
# Carol
# Digite seu ano de nascimento (formato AAAA)
# 01/12/2006
# OláCarol, você nasceu em01/12/2006

# %%
# Tarefa 5
nome_usuario = input("informe seu nome: ")
print(f"Olá, {nome_usuario}!")
ano_nascimento = input("informe seu ano de nascimento: ")
idade= 2025 - int(ano_nascimento)
print(f"{nome_usuario} tem {idade}, {nome_usuario * idade}")
# Out:
# informe seu nome: Carol
# Olá, Carol!
# informe seu ano de nascimento: 2006
# Carol tem 19, CarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarolCarol

# %%
# Tarefa 6
n1 = float(input("informe a primeira nota: "))
n2 = float(input("informe a segunda nota: "))
n3 = float(input("informe a terceira nota"))
media = (n1+n2+n3)/3
print("media: ", media)
# Out:
# informe a primeira nota: 20
# informe a segunda nota: 41
# informe a terceira nota20
# media:  27.0

# %%
# Tarefa 7
nota1 = float(input("Informe a primeira nota: "))
peso1 = float(input("Informe o peso da primeira nota: "))
nota2 = float(input("Informe a segunda nota: "))
peso2 = float(input("Informe o peso da segunda nota: "))
nota3 = float(input("Informe a terceira nota: "))
peso3 = float(input("Informe o peso da terceira nota: "))

media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)

print(f"A média ponderada é: {media_ponderada}")
# Out:
# Informe a primeira nota: 50
# Informe o peso da primeira nota: 41
# Informe a segunda nota: 12
# Informe o peso da segunda nota: 23
# Informe a terceira nota: 63
# Informe o peso da terceira nota: 52
# A média ponderada é: 48.293103448275865

# %%
# Tarefa 8
numero = input("Informe um número: ")
soma_digitos = sum(int(digito) for digito in numero)
print(f"A soma dos dígitos é: {soma_digitos}")
# Out:
# Informe um número: 8
# A soma dos dígitos é: 8

# %%
# Tarefa 9
palavra = input("Informe uma palavra: ")
palavra_invertida = palavra[::-1]
print(f"A palavra invertida é: {palavra_invertida}")
# Out:
# Informe uma palavra: carol
# A palavra invertida é: lorac
